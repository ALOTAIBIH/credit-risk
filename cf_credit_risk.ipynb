# %%
import pandas as pd # data analysis
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/hissah/Desktop/dirctive explanation/scienario/credit_risk.csv')
data.head()
# Out:
#    emp_length  loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  \
# 0           0       5000         5000           4975.0    36     10.65
# 1           1       2500         2500           2500.0    60     15.27
# 2           2       2400         2400           2400.0    36     15.96
# 3           3      10000        10000          10000.0    36     13.49
# 4           4       3000         3000           3000.0    60     12.69
#
#    installment grade sub_grade                 emp_title  ...  \
# 0       162.87     B        B2                       NaN  ...
# 1        59.83     C        C4                     Ryder  ...
# 2        84.33     C        C5                       NaN  ...
# 3       339.31     C        C1       AIR RESOURCES BOARD  ...
# 4        67.79     B        B5  University Medical Group  ...
#
#   last_pymnt_d_is_Oct-2016  last_pymnt_d_is_Sep-2008 last_pymnt_d_is_Sep-2009  \
# 0                        0                         0                        0
# ...

# %%
data.shape
# Out:
# (39786, 821)

# %%
data.shape
# Out:
# (39786, 821)

# %%
#find the number of unique values in each column
drop_columns = []

for col in data.columns:
    data[col].dropna(inplace=True)
    unique = data[col].unique()
    num_unique = len(unique)
    
    if num_unique == 1:
        drop_columns.append(col)
    else:
        pass
    
data = data.drop(drop_columns, axis=1)
print(drop_columns)
# Out:
# []

# %%
null_counts = data.isnull().sum()
null_counts, data.shape[0]
# Out:
# (emp_length                  0
#  loan_amnt                   0
#  funded_amnt                 0
#  funded_amnt_inv             0
#  term                        0
#                             ..
#  last_pymnt_d_is_Sep-2012    0
#  last_pymnt_d_is_Sep-2013    0
#  last_pymnt_d_is_Sep-2014    0
#  last_pymnt_d_is_Sep-2015    0
#  last_pymnt_d_is_Sep-2016    0
#  Length: 821, dtype: int64,
#  39786)

# %%
data.isnull().any()
# Out:
# emp_length                  False
# loan_amnt                   False
# funded_amnt                 False
# funded_amnt_inv             False
# term                        False
#                             ...
# last_pymnt_d_is_Sep-2012    False
# last_pymnt_d_is_Sep-2013    False
# last_pymnt_d_is_Sep-2014    False
# last_pymnt_d_is_Sep-2015    False
# last_pymnt_d_is_Sep-2016    False
# Length: 821, dtype: bool

# %%
data.shape
# Out:
# (39786, 821)

# %%
data.isnull()
# Out:
#        emp_length  loan_amnt  funded_amnt  funded_amnt_inv   term  int_rate  \
# 0           False      False        False            False  False     False
# 1           False      False        False            False  False     False
# 2           False      False        False            False  False     False
# 3           False      False        False            False  False     False
# 4           False      False        False            False  False     False
# ...           ...        ...          ...              ...    ...       ...
# 39781       False      False        False            False  False     False
# 39782       False      False        False            False  False     False
# 39783       False      False        False            False  False     False
# 39784       False      False        False            False  False     False
# 39785       False      False        False            False  False     False
#
#        installment  grade  sub_grade  emp_title  ...  \
# ...

# %%
data.isna().sum()
# Out:
# emp_length                  0
# loan_amnt                   0
# funded_amnt                 0
# funded_amnt_inv             0
# term                        0
#                            ..
# last_pymnt_d_is_Sep-2012    0
# last_pymnt_d_is_Sep-2013    0
# last_pymnt_d_is_Sep-2014    0
# last_pymnt_d_is_Sep-2015    0
# last_pymnt_d_is_Sep-2016    0
# Length: 821, dtype: int64

# %%
data.isna().any().sum()
# Out:
# 9

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 39781    False
# 39782    False
# 39783    False
# 39784    False
# 39785    False
# Length: 39786, dtype: bool

# %%
data.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
# Out:
#        emp_length  loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  \
# 0               0       5000         5000           4975.0    36     10.65
# 1               1       2500         2500           2500.0    60     15.27
# 2               2       2400         2400           2400.0    36     15.96
# 3               3      10000        10000          10000.0    36     13.49
# 4               4       3000         3000           3000.0    60     12.69
# ...           ...        ...          ...              ...   ...       ...
# 39781       39781       2500         2500           1075.0    36      8.07
# 39782       39782       8500         8500            875.0    36     10.28
# 39783       39783       5000         5000           1325.0    36      8.07
# 39784       39784       5000         5000            650.0    36      7.43
# 39785       39785       7500         7500            800.0    36     13.75
#
# ...

# %%
data.dtypes
# Out:
# emp_length                    int64
# loan_amnt                     int64
# funded_amnt                   int64
# funded_amnt_inv             float64
# term                          int64
#                              ...
# last_pymnt_d_is_Sep-2012      int64
# last_pymnt_d_is_Sep-2013      int64
# last_pymnt_d_is_Sep-2014      int64
# last_pymnt_d_is_Sep-2015      int64
# last_pymnt_d_is_Sep-2016      int64
# Length: 821, dtype: object

# %%
obj_df = data.select_dtypes(include=['object']).copy()
obj_df.head()
# Out:
#   grade sub_grade                 emp_title home_ownership  \
# 0     B        B2                       NaN           RENT
# 1     C        C4                     Ryder           RENT
# 2     C        C5                       NaN           RENT
# 3     C        C1       AIR RESOURCES BOARD           RENT
# 4     B        B5  University Medical Group           RENT
#
#   verification_status                                               desc  \
# 0            Verified    Borrower added on 12/22/11 > I need to upgra...
# 1     Source Verified    Borrower added on 12/22/11 > I plan to use t...
# 2        Not Verified                                                NaN
# 3     Source Verified    Borrower added on 12/21/11 > to pay for prop...
# 4     Source Verified    Borrower added on 12/21/11 > I plan on combi...
#
#           purpose                 title zip_code addr_state last_credit_pull_d
# 0     credit_card              Computer    860xx         AZ             Apr-17
# ...

# %%
data.shape
# Out:
# (39786, 821)

# %%
data = data.drop(["home_ownership_is_MORTGAGE"], axis=1)

# %%
data = data.drop(["home_ownership_is_NONE","home_ownership_is_OWN","home_ownership_is_RENT","purpose_is_car","purpose_is_credit_card","purpose_is_debt_consolidation","purpose_is_educational","purpose_is_home_improvement","purpose_is_house"], axis=1)

# %%
cols = ['funded_amnt','funded_amnt_inv','grade']
data = data.drop(cols, axis=1)
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'sub_grade', 'emp_title', 'home_ownership', 'annual_inc',
#        'verification_status',
#        ...
#        'last_pymnt_d_is_Oct-2016', 'last_pymnt_d_is_Sep-2008',
#        'last_pymnt_d_is_Sep-2009', 'last_pymnt_d_is_Sep-2010',
#        'last_pymnt_d_is_Sep-2011', 'last_pymnt_d_is_Sep-2012',
#        'last_pymnt_d_is_Sep-2013', 'last_pymnt_d_is_Sep-2014',
#        'last_pymnt_d_is_Sep-2015', 'last_pymnt_d_is_Sep-2016'],
#       dtype='object', length=808)

# %%
cols = ['last_pymnt_d_is_Oct-2016', 'last_pymnt_d_is_Sep-2008','last_pymnt_d_is_Sep-2009', 'last_pymnt_d_is_Sep-2010','last_pymnt_d_is_Sep-2011', 'last_pymnt_d_is_Sep-2012','last_pymnt_d_is_Sep-2013', 'last_pymnt_d_is_Sep-2014','last_pymnt_d_is_Sep-2015', 'last_pymnt_d_is_Sep-2016']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... last_pymnt_d_is_Nov-2015 last_pymnt_d_is_Nov-2016  \
# 0  ...                        0                        0
# ...

# %%
cols =['last_pymnt_d_is_Nov-2014','last_pymnt_d_is_Nov-2015','last_pymnt_d_is_Oct-2008','last_pymnt_d_is_Oct-2009','last_pymnt_d_is_Oct-2010','last_pymnt_d_is_Oct-2011','last_pymnt_d_is_Oct-2012','last_pymnt_d_is_Oct-2013','last_pymnt_d_is_Oct-2014','last_pymnt_d_is_Oct-2015']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... last_pymnt_d_is_May-2014 last_pymnt_d_is_May-2015  \
# 0  ...                        0                        0
# ...

# %%
cols =['last_pymnt_d_is_May-2013','last_pymnt_d_is_May-2014','last_pymnt_d_is_May-2015','last_pymnt_d_is_May-2016','last_pymnt_d_is_Nov-2008','last_pymnt_d_is_Nov-2009','last_pymnt_d_is_Nov-2010','last_pymnt_d_is_Nov-2011','last_pymnt_d_is_Nov-2012','last_pymnt_d_is_Nov-2013']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... last_pymnt_d_is_Mar-2013 last_pymnt_d_is_Mar-2014  \
# 0  ...                        0                        0
# ...

# %%
cols =['last_pymnt_d_is_Mar-2012','last_pymnt_d_is_Mar-2013','last_pymnt_d_is_Mar-2014','last_pymnt_d_is_Mar-2015','last_pymnt_d_is_Mar-2016','last_pymnt_d_is_May-2008','last_pymnt_d_is_May-2009','last_pymnt_d_is_May-2010','last_pymnt_d_is_May-2011','last_pymnt_d_is_May-2012']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... last_pymnt_d_is_Jun-2012 last_pymnt_d_is_Jun-2013  \
# 0  ...                        0                        0
# ...

# %%
cols =['last_pymnt_d_is_Jun-2011','last_pymnt_d_is_Jun-2012','last_pymnt_d_is_Jun-2013','last_pymnt_d_is_Jun-2014','last_pymnt_d_is_Jun-2015','last_pymnt_d_is_Jun-2016','last_pymnt_d_is_Mar-2008','last_pymnt_d_is_Mar-2009','last_pymnt_d_is_Mar-2010','last_pymnt_d_is_Mar-2011']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... last_pymnt_d_is_Jul-2011 last_pymnt_d_is_Jul-2012  \
# 0  ...                        0                        0
# ...

# %%
cols =['last_pymnt_d_is_Jun-2011','last_pymnt_d_is_Jun-2012','last_pymnt_d_is_Jun-2013','last_pymnt_d_is_Jun-2014','last_pymnt_d_is_Jun-2015','last_pymnt_d_is_Jun-2016','last_pymnt_d_is_Mar-2008','last_pymnt_d_is_Mar-2009','last_pymnt_d_is_Mar-2010','last_pymnt_d_is_Mar-2011']
data = data.drop(cols, axis=1)
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-183-dca7b3e49ed4> in <module>
#       1 cols =['last_pymnt_d_is_Jun-2011','last_pymnt_d_is_Jun-2012','last_pymnt_d_is_Jun-2013','last_pymnt_d_is_Jun-2014','last_pymnt_d_is_Jun-2015','last_pymnt_d_is_Jun-2016','last_pymnt_d_is_Mar-2008','last_pymnt_d_is_Mar-2009','last_pymnt_d_is_Mar-2010','last_pymnt_d_is_Mar-2011']
# ----> 2 data = data.drop(cols, axis=1)
#       3 data.head()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ...

# %%
cols =['last_pymnt_d_is_Jul-2010','last_pymnt_d_is_Jul-2011','last_pymnt_d_is_Jul-2012','last_pymnt_d_is_Jul-2013','last_pymnt_d_is_Jul-2014','last_pymnt_d_is_Jul-2015','last_pymnt_d_is_Jul-2016','last_pymnt_d_is_Jun-2008','last_pymnt_d_is_Jun-2009','last_pymnt_d_is_Jun-2010']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... last_pymnt_d_is_Jan-2011 last_pymnt_d_is_Jan-2012  \
# 0  ...                        0                        0
# ...

# %%
cols =['last_pymnt_d_is_Jan-2009','last_pymnt_d_is_Jan-2010','last_pymnt_d_is_Jan-2011','last_pymnt_d_is_Jan-2012','last_pymnt_d_is_Jan-2013','last_pymnt_d_is_Jan-2014','last_pymnt_d_is_Jan-2015','last_pymnt_d_is_Jan-2016','last_pymnt_d_is_Jul-2008','last_pymnt_d_is_Jul-2009']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... last_pymnt_d_is_Feb-2011 last_pymnt_d_is_Feb-2012  \
# 0  ...                        0                        0
# ...

# %%
cols =['last_pymnt_d_is_Feb-2008','last_pymnt_d_is_Feb-2009','last_pymnt_d_is_Feb-2010','last_pymnt_d_is_Feb-2011','last_pymnt_d_is_Feb-2012','last_pymnt_d_is_Feb-2013','last_pymnt_d_is_Feb-2014','last_pymnt_d_is_Feb-2015','last_pymnt_d_is_Feb-2016','last_pymnt_d_is_Jan-2008']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... last_pymnt_d_is_Dec-2010 last_pymnt_d_is_Dec-2011  \
# 0  ...                        0                        0
# ...

# %%
cols =['last_pymnt_d_is_Aug-2016','last_pymnt_d_is_Dec-2008','last_pymnt_d_is_Dec-2009','last_pymnt_d_is_Dec-2010','last_pymnt_d_is_Dec-2011','last_pymnt_d_is_Dec-2012','last_pymnt_d_is_Dec-2013','last_pymnt_d_is_Dec-2014','last_pymnt_d_is_Dec-2015','last_pymnt_d_is_Dec-2016']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... last_pymnt_d_is_Aug-2009 last_pymnt_d_is_Aug-2010  \
# 0  ...                        0                        0
# ...

# %%
data.shape
# Out:
# (39786, 718)

# %%
cols =['last_pymnt_d_is_Apr-2015','last_pymnt_d_is_Apr-2016','last_pymnt_d_is_Aug-2008','last_pymnt_d_is_Aug-2009','last_pymnt_d_is_Aug-2010','last_pymnt_d_is_Aug-2011','last_pymnt_d_is_Aug-2012','last_pymnt_d_is_Aug-2013','last_pymnt_d_is_Aug-2014','last_pymnt_d_is_Aug-2015']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... last_pymnt_d_is_Apr-2009 last_pymnt_d_is_Apr-2010  \
# 0  ...                        0                        0
# ...

# %%
dat = data.select_dtypes(include=['object']).copy()
dat.head()
# Out:
#   sub_grade                 emp_title home_ownership verification_status  \
# 0        B2                       NaN           RENT            Verified
# 1        C4                     Ryder           RENT     Source Verified
# 2        C5                       NaN           RENT        Not Verified
# 3        C1       AIR RESOURCES BOARD           RENT     Source Verified
# 4        B5  University Medical Group           RENT     Source Verified
#
#                                                 desc         purpose  \
# 0    Borrower added on 12/22/11 > I need to upgra...     credit_card
# 1    Borrower added on 12/22/11 > I plan to use t...             car
# 2                                                NaN  small_business
# 3    Borrower added on 12/21/11 > to pay for prop...           other
# 4    Borrower added on 12/21/11 > I plan on combi...           other
#
#                   title zip_code addr_state last_credit_pull_d
# ...

# %%
cols =['earliest_cr_line_is_Sep-2002','earliest_cr_line_is_Sep-2003','earliest_cr_line_is_Sep-2004','last_pymnt_d_is_Apr-2008','last_pymnt_d_is_Apr-2009','last_pymnt_d_is_Apr-2010','last_pymnt_d_is_Apr-2011','last_pymnt_d_is_Apr-2012','last_pymnt_d_is_Apr-2013','last_pymnt_d_is_Apr-2014']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... earliest_cr_line_is_Sep-2000 earliest_cr_line_is_Sep-2001  \
# ...

# %%
cols =['earliest_cr_line_is_Sep-1992','earliest_cr_line_is_Sep-1993','earliest_cr_line_is_Sep-1994','earliest_cr_line_is_Sep-1995','earliest_cr_line_is_Sep-1996','earliest_cr_line_is_Sep-1997','earliest_cr_line_is_Sep-1998','earliest_cr_line_is_Sep-1999','earliest_cr_line_is_Sep-2000','earliest_cr_line_is_Sep-2001']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... earliest_cr_line_is_Sep-1990 earliest_cr_line_is_Sep-1991  \
# ...

# %%
cols =['earliest_cr_line_is_Sep-1981','earliest_cr_line_is_Sep-1983','earliest_cr_line_is_Sep-1984','earliest_cr_line_is_Sep-1985','earliest_cr_line_is_Sep-1986','earliest_cr_line_is_Sep-1987','earliest_cr_line_is_Sep-1988','earliest_cr_line_is_Sep-1989','earliest_cr_line_is_Sep-1990','earliest_cr_line_is_Sep-1991']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... earliest_cr_line_is_Sep-1980 earliest_cr_line_is_Sep-1982  \
# ...

# %%
cols =['earliest_cr_line_is_Oct-1998','earliest_cr_line_is_Oct-1999','earliest_cr_line_is_Oct-2000','earliest_cr_line_is_Oct-2001','earliest_cr_line_is_Oct-2002','earliest_cr_line_is_Oct-2003','earliest_cr_line_is_Oct-2004','earliest_cr_line_is_Sep-1964','earliest_cr_line_is_Sep-1973','earliest_cr_line_is_Sep-1976']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... earliest_cr_line_is_Sep-1980 earliest_cr_line_is_Sep-1982  \
# ...

# %%
cols =['issue_d_is_2011-11-01 00:00:00','issue_d_is_2011-12-01 00:00:00','earliest_cr_line_is_Jan-2000','earliest_cr_line_is_Oct-1991','earliest_cr_line_is_Oct-1992','earliest_cr_line_is_Oct-1993','earliest_cr_line_is_Oct-1994','earliest_cr_line_is_Oct-1995','earliest_cr_line_is_Oct-1996','earliest_cr_line_is_Oct-1997']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... earliest_cr_line_is_Sep-1980 earliest_cr_line_is_Sep-1982  \
# ...

# %%
cols =['issue_d_is_2011-01-01 00:00:00','issue_d_is_2011-02-01 00:00:00','issue_d_is_2011-03-01 00:00:00','issue_d_is_2011-04-01 00:00:00','issue_d_is_2011-05-01 00:00:00','issue_d_is_2011-06-01 00:00:00','issue_d_is_2011-07-01 00:00:00','issue_d_is_2011-08-01 00:00:00','issue_d_is_2011-09-01 00:00:00','issue_d_is_2011-10-01 00:00:00']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... earliest_cr_line_is_Sep-1980 earliest_cr_line_is_Sep-1982  \
# ...

# %%
cols =['issue_d_is_2010-03-01 00:00:00','issue_d_is_2010-04-01 00:00:00','issue_d_is_2010-05-01 00:00:00','issue_d_is_2010-06-01 00:00:00','issue_d_is_2010-07-01 00:00:00','issue_d_is_2010-08-01 00:00:00','issue_d_is_2010-09-01 00:00:00','issue_d_is_2010-10-01 00:00:00','issue_d_is_2010-11-01 00:00:00','issue_d_is_2010-12-01 00:00:00']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... earliest_cr_line_is_Sep-1980 earliest_cr_line_is_Sep-1982  \
# ...

# %%
cols =['issue_d_is_2009-05-01 00:00:00','issue_d_is_2009-06-01 00:00:00','issue_d_is_2009-07-01 00:00:00','issue_d_is_2009-08-01 00:00:00','issue_d_is_2009-09-01 00:00:00','issue_d_is_2009-10-01 00:00:00','issue_d_is_2009-11-01 00:00:00','issue_d_is_2009-12-01 00:00:00','issue_d_is_2010-01-01 00:00:00','issue_d_is_2010-02-01 00:00:00']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... earliest_cr_line_is_Sep-1980 earliest_cr_line_is_Sep-1982  \
# ...

# %%
cols =['issue_d_is_2008-07-01 00:00:00','issue_d_is_2008-08-01 00:00:00','issue_d_is_2008-09-01 00:00:00','issue_d_is_2008-10-01 00:00:00','issue_d_is_2008-11-01 00:00:00','issue_d_is_2008-12-01 00:00:00','issue_d_is_2009-01-01 00:00:00','issue_d_is_2009-02-01 00:00:00','issue_d_is_2009-03-01 00:00:00','issue_d_is_2009-04-01 00:00:00']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... earliest_cr_line_is_Sep-1980 earliest_cr_line_is_Sep-1982  \
# ...

# %%
cols =['issue_d_is_2007-09-01 00:00:00','issue_d_is_2007-10-01 00:00:00','issue_d_is_2007-11-01 00:00:00','issue_d_is_2007-12-01 00:00:00','issue_d_is_2008-01-01 00:00:00','issue_d_is_2008-02-01 00:00:00','issue_d_is_2008-03-01 00:00:00','issue_d_is_2008-04-01 00:00:00','issue_d_is_2008-05-01 00:00:00','issue_d_is_2008-06-01 00:00:00']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... earliest_cr_line_is_Sep-1980 earliest_cr_line_is_Sep-1982  \
# ...

# %%
cols =['emp_length_is_2 years','emp_length_is_3 years','emp_length_is_4 years','emp_length_is_5 years','emp_length_is_6 years','emp_length_is_7 years','emp_length_is_8 years','emp_length_is_9 years','emp_length_is_< 1 year','issue_d_is_2007-08-01 00:00:00']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... earliest_cr_line_is_Sep-1980 earliest_cr_line_is_Sep-1982  \
# ...

# %%
cols =['addr_state_is_UT','addr_state_is_VA','addr_state_is_VT','addr_state_is_WA','addr_state_is_WI','addr_state_is_WV','addr_state_is_WY','emp_length_is_1 year','emp_length_is_10+ years']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... earliest_cr_line_is_Sep-1980 earliest_cr_line_is_Sep-1982  \
# ...

# %%
cols =['addr_state_is_OH','addr_state_is_OK','addr_state_is_OR','addr_state_is_PA','addr_state_is_RI','addr_state_is_SC','addr_state_is_SD','addr_state_is_TN','addr_state_is_TX']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... earliest_cr_line_is_Sep-1980 earliest_cr_line_is_Sep-1982  \
# ...

# %%
cols =['addr_state_is_MS','addr_state_is_MT','addr_state_is_NC','addr_state_is_NE','addr_state_is_NH','addr_state_is_NJ','addr_state_is_NM','addr_state_is_NV','addr_state_is_NY']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... earliest_cr_line_is_Sep-1980 earliest_cr_line_is_Sep-1982  \
# ...

# %%
cols =['addr_state_is_KS','addr_state_is_KY','addr_state_is_LA','addr_state_is_MA','addr_state_is_MD','addr_state_is_ME','addr_state_is_MI','addr_state_is_MN','addr_state_is_MO']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... earliest_cr_line_is_Sep-1980 earliest_cr_line_is_Sep-1982  \
# ...

# %%
cols =['addr_state_is_DC','addr_state_is_DE','addr_state_is_FL','addr_state_is_GA','addr_state_is_HI','addr_state_is_IA','addr_state_is_ID','addr_state_is_IL','addr_state_is_IN']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... earliest_cr_line_is_Sep-1980 earliest_cr_line_is_Sep-1982  \
# ...

# %%
cols =['grade_is_F','grade_is_G','addr_state_is_AK','addr_state_is_AL','addr_state_is_AR','addr_state_is_AZ','addr_state_is_CA','addr_state_is_CO','addr_state_is_CT']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... earliest_cr_line_is_Sep-1980 earliest_cr_line_is_Sep-1982  \
# ...

# %%
cols =['purpose_is_renewable_energy','purpose_is_small_business','purpose_is_vacation','purpose_is_wedding','grade_is_A','grade_is_B','grade_is_C','grade_is_D','grade_is_E']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... earliest_cr_line_is_Sep-1980 earliest_cr_line_is_Sep-1982  \
# ...

# %%
cols =['purpose_is_major_purchase','purpose_is_medical','purpose_is_moving','purpose_is_other']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0           0       5000    36     10.65       162.87        B2
# 1           1       2500    60     15.27        59.83        C4
# 2           2       2400    36     15.96        84.33        C5
# 3           3      10000    36     13.49       339.31        C1
# 4           4       3000    60     12.69        67.79        B5
#
#                   emp_title home_ownership  annual_inc verification_status  \
# 0                       NaN           RENT     24000.0            Verified
# 1                     Ryder           RENT     30000.0     Source Verified
# 2                       NaN           RENT     12252.0        Not Verified
# 3       AIR RESOURCES BOARD           RENT     49200.0     Source Verified
# 4  University Medical Group           RENT     80000.0     Source Verified
#
#    ... earliest_cr_line_is_Sep-1980 earliest_cr_line_is_Sep-1982  \
# ...

# %%
data = data.drop(["last_credit_pull_d", "addr_state", "title","mths_since_last_delinq","mths_since_last_record","collections_12_mths_ex_med","chargeoff_within_12_mths","tax_liens"], axis=1)

# %%
data[data.isnull().any(axis=1)]
# Out:
#        emp_length  loan_amnt  term  int_rate  installment sub_grade  \
# 0               0       5000    36     10.65       162.87        B2
# 2               2       2400    36     15.96        84.33        C5
# 5               5       5000    36      7.90       156.46        A4
# 8               8       5600    60     21.28       152.39        F2
# 11             11      12000    36     12.69       402.54        B5
# ...           ...        ...   ...       ...          ...       ...
# 39775       39775       5000    36      8.07       156.84        A4
# 39778       39778       5000    36     11.22       164.23        C4
# 39779       39779       5000    36      7.43       155.38        A2
# 39783       39783       5000    36      8.07       156.84        A4
# 39784       39784       5000    36      7.43       155.38        A2
#
#                   emp_title home_ownership  annual_inc verification_status  \
# ...

# %%
data["sub_grade"].value_counts()
# Out:
# B3    2924
# A4    2886
# A5    2742
# B5    2709
# B4    2514
# C1    2142
# B2    2058
# C2    2014
# B1    1830
# A3    1810
# C3    1529
# A2    1508
# D2    1352
# C4    1238
# C5    1188
# D3    1178
# A1    1139
# D4     986
# D1     931
# D5     878
# E1     768
# E2     659
# E3     556
# E4     455
# E5     420
# F1     329
# F2     251
# F3     187
# F4     169
# F5     118
# G1     105
# G2      78
# G4      56
# G3      49
# G5      30
# Name: sub_grade, dtype: int64

# %%
data = data.drop(["sub_grade"], axis=1)

# %%
data["home_ownership"].value_counts()
# Out:
# RENT        18918
# MORTGAGE    17703
# OWN          3064
# OTHER          98
# NONE            3
# Name: home_ownership, dtype: int64

# %%
data["verification_status"].value_counts()
# Out:
# Not Verified       16926
# Verified           12844
# Source Verified    10016
# Name: verification_status, dtype: int64

# %%
data["purpose"].value_counts()
# Out:
# debt_consolidation    18676
# credit_card            5137
# other                  4001
# home_improvement       2985
# major_purchase         2188
# small_business         1831
# car                    1551
# wedding                 948
# medical                 695
# moving                  583
# house                   382
# vacation                381
# educational             325
# renewable_energy        103
# Name: purpose, dtype: int64

# %%
data["last_credit_pull_d"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'last_credit_pull_d'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-217-5bcd95045b74> in <module>
# ...

# %%
data.shape
# Out:
# (39786, 522)

# %%
mapping_dict = {
            "home_ownership": {"RENT": 0, "MORTGAGE": -3, "OWN": -2, "NONE": -1}, 
            "verification_status": {"Not Verified": 0, "Verified": -2, "Source Verified": -1},
            "purpose": {"debt_consolidation": 0,"educational": -13, "moving": -12, "vacation": -11, "house": -10, "renewable_energy": -9, "other": -8, "credit_card": -7,"home_improvement": -6,  
                "small_business": -5 ,"major_purchase": -4,  "car": -3,  "wedding": -2, 
                 "medical": -1}}
data = data.replace(mapping_dict)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  \
# 0           0       5000    36     10.65       162.87
# 1           1       2500    60     15.27        59.83
# 2           2       2400    36     15.96        84.33
# 3           3      10000    36     13.49       339.31
# 4           4       3000    60     12.69        67.79
#
#                   emp_title home_ownership  annual_inc  verification_status  \
# 0                       NaN              0     24000.0                   -2
# 1                     Ryder              0     30000.0                   -1
# 2                       NaN              0     12252.0                    0
# 3       AIR RESOURCES BOARD              0     49200.0                   -1
# 4  University Medical Group              0     80000.0                   -1
#
#                                                 desc  ...  \
# 0    Borrower added on 12/22/11 > I need to upgra...  ...
# 1    Borrower added on 12/22/11 > I plan to use t...  ...
# ...

# %%
data.to_csv(r'cf_loans_clean26.csv',index=False)

# %%
data.shape
# Out:
# (39786, 522)

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'emp_title', 'home_ownership', 'annual_inc', 'verification_status',
#        'desc',
#        ...
#        'earliest_cr_line_is_Sep-1980', 'earliest_cr_line_is_Sep-1982',
#        'earliest_cr_line_is_Sep-2005', 'earliest_cr_line_is_Sep-2006',
#        'earliest_cr_line_is_Sep-2007', 'earliest_cr_line_is_Sep-2008',
#        'last_pymnt_d_is_Apr-2017', 'last_pymnt_d_is_Feb-2017',
#        'last_pymnt_d_is_Jan-2017', 'last_pymnt_d_is_Nov-2016'],
#       dtype='object', length=522)

# %%
data.dtypes
# Out:
# emp_length                        int64
# loan_amnt                         int64
# term                              int64
# int_rate                        float64
# installment                     float64
#                                  ...
# earliest_cr_line_is_Sep-2008      int64
# last_pymnt_d_is_Apr-2017          int64
# last_pymnt_d_is_Feb-2017          int64
# last_pymnt_d_is_Jan-2017          int64
# last_pymnt_d_is_Nov-2016          int64
# Length: 522, dtype: object

# %%
cols =['earliest_cr_line_is_Nov-2000', 'earliest_cr_line_is_Nov-2001',
       'earliest_cr_line_is_Nov-2002', 'earliest_cr_line_is_Nov-2003',
       'earliest_cr_line_is_Nov-2004', 'earliest_cr_line_is_Oct-1979',
       'earliest_cr_line_is_Oct-1980', 'earliest_cr_line_is_Oct-1984',
       'earliest_cr_line_is_Oct-1989', 'earliest_cr_line_is_Oct-1990']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  \
# 0           0       5000    36     10.65       162.87
# 1           1       2500    60     15.27        59.83
# 2           2       2400    36     15.96        84.33
# 3           3      10000    36     13.49       339.31
# 4           4       3000    60     12.69        67.79
#
#                   emp_title home_ownership  annual_inc  verification_status  \
# 0                       NaN              0     24000.0                   -2
# 1                     Ryder              0     30000.0                   -1
# 2                       NaN              0     12252.0                    0
# 3       AIR RESOURCES BOARD              0     49200.0                   -1
# 4  University Medical Group              0     80000.0                   -1
#
#                                                 desc  ...  \
# 0    Borrower added on 12/22/11 > I need to upgra...  ...
# 1    Borrower added on 12/22/11 > I plan to use t...  ...
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'emp_title', 'home_ownership', 'annual_inc', 'verification_status',
#        'desc',
#        ...
#        'earliest_cr_line_is_Sep-1980', 'earliest_cr_line_is_Sep-1982',
#        'earliest_cr_line_is_Sep-2005', 'earliest_cr_line_is_Sep-2006',
#        'earliest_cr_line_is_Sep-2007', 'earliest_cr_line_is_Sep-2008',
#        'last_pymnt_d_is_Apr-2017', 'last_pymnt_d_is_Feb-2017',
#        'last_pymnt_d_is_Jan-2017', 'last_pymnt_d_is_Nov-2016'],
#       dtype='object', length=512)

# %%
cols =['earliest_cr_line_is_Nov-1990', 'earliest_cr_line_is_Nov-1991',
       'earliest_cr_line_is_Nov-1992', 'earliest_cr_line_is_Nov-1993',
       'earliest_cr_line_is_Nov-1994', 'earliest_cr_line_is_Nov-1995',
       'earliest_cr_line_is_Nov-1996', 'earliest_cr_line_is_Nov-1997',
       'earliest_cr_line_is_Nov-1998', 'earliest_cr_line_is_Nov-1999']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  \
# 0           0       5000    36     10.65       162.87
# 1           1       2500    60     15.27        59.83
# 2           2       2400    36     15.96        84.33
# 3           3      10000    36     13.49       339.31
# 4           4       3000    60     12.69        67.79
#
#                   emp_title home_ownership  annual_inc  verification_status  \
# 0                       NaN              0     24000.0                   -2
# 1                     Ryder              0     30000.0                   -1
# 2                       NaN              0     12252.0                    0
# 3       AIR RESOURCES BOARD              0     49200.0                   -1
# 4  University Medical Group              0     80000.0                   -1
#
#                                                 desc  ...  \
# 0    Borrower added on 12/22/11 > I need to upgra...  ...
# 1    Borrower added on 12/22/11 > I plan to use t...  ...
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'emp_title', 'home_ownership', 'annual_inc', 'verification_status',
#        'desc',
#        ...
#        'earliest_cr_line_is_Sep-1980', 'earliest_cr_line_is_Sep-1982',
#        'earliest_cr_line_is_Sep-2005', 'earliest_cr_line_is_Sep-2006',
#        'earliest_cr_line_is_Sep-2007', 'earliest_cr_line_is_Sep-2008',
#        'last_pymnt_d_is_Apr-2017', 'last_pymnt_d_is_Feb-2017',
#        'last_pymnt_d_is_Jan-2017', 'last_pymnt_d_is_Nov-2016'],
#       dtype='object', length=502)

# %%
cols =['earliest_cr_line_is_Nov-1976', 'earliest_cr_line_is_Nov-1981',
       'earliest_cr_line_is_Nov-1982', 'earliest_cr_line_is_Nov-1983',
       'earliest_cr_line_is_Nov-1984', 'earliest_cr_line_is_Nov-1985',
       'earliest_cr_line_is_Nov-1986', 'earliest_cr_line_is_Nov-1987',
       'earliest_cr_line_is_Nov-1988', 'earliest_cr_line_is_Nov-1989']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  \
# 0           0       5000    36     10.65       162.87
# 1           1       2500    60     15.27        59.83
# 2           2       2400    36     15.96        84.33
# 3           3      10000    36     13.49       339.31
# 4           4       3000    60     12.69        67.79
#
#                   emp_title home_ownership  annual_inc  verification_status  \
# 0                       NaN              0     24000.0                   -2
# 1                     Ryder              0     30000.0                   -1
# 2                       NaN              0     12252.0                    0
# 3       AIR RESOURCES BOARD              0     49200.0                   -1
# 4  University Medical Group              0     80000.0                   -1
#
#                                                 desc  ...  \
# 0    Borrower added on 12/22/11 > I need to upgra...  ...
# 1    Borrower added on 12/22/11 > I plan to use t...  ...
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'emp_title', 'home_ownership', 'annual_inc', 'verification_status',
#        'desc',
#        ...
#        'earliest_cr_line_is_Sep-1980', 'earliest_cr_line_is_Sep-1982',
#        'earliest_cr_line_is_Sep-2005', 'earliest_cr_line_is_Sep-2006',
#        'earliest_cr_line_is_Sep-2007', 'earliest_cr_line_is_Sep-2008',
#        'last_pymnt_d_is_Apr-2017', 'last_pymnt_d_is_Feb-2017',
#        'last_pymnt_d_is_Jan-2017', 'last_pymnt_d_is_Nov-2016'],
#       dtype='object', length=492)

# %%
cols =['earliest_cr_line_is_May-1996', 'earliest_cr_line_is_May-1997',
       'earliest_cr_line_is_May-1998', 'earliest_cr_line_is_May-1999',
       'earliest_cr_line_is_May-2000', 'earliest_cr_line_is_May-2001',
       'earliest_cr_line_is_May-2002', 'earliest_cr_line_is_May-2003',
       'earliest_cr_line_is_May-2004', 'earliest_cr_line_is_Nov-1972']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  \
# 0           0       5000    36     10.65       162.87
# 1           1       2500    60     15.27        59.83
# 2           2       2400    36     15.96        84.33
# 3           3      10000    36     13.49       339.31
# 4           4       3000    60     12.69        67.79
#
#                   emp_title home_ownership  annual_inc  verification_status  \
# 0                       NaN              0     24000.0                   -2
# 1                     Ryder              0     30000.0                   -1
# 2                       NaN              0     12252.0                    0
# 3       AIR RESOURCES BOARD              0     49200.0                   -1
# 4  University Medical Group              0     80000.0                   -1
#
#                                                 desc  ...  \
# 0    Borrower added on 12/22/11 > I need to upgra...  ...
# 1    Borrower added on 12/22/11 > I plan to use t...  ...
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'emp_title', 'home_ownership', 'annual_inc', 'verification_status',
#        'desc',
#        ...
#        'earliest_cr_line_is_Sep-1980', 'earliest_cr_line_is_Sep-1982',
#        'earliest_cr_line_is_Sep-2005', 'earliest_cr_line_is_Sep-2006',
#        'earliest_cr_line_is_Sep-2007', 'earliest_cr_line_is_Sep-2008',
#        'last_pymnt_d_is_Apr-2017', 'last_pymnt_d_is_Feb-2017',
#        'last_pymnt_d_is_Jan-2017', 'last_pymnt_d_is_Nov-2016'],
#       dtype='object', length=482)

# %%
cols =['earliest_cr_line_is_May-1985', 'earliest_cr_line_is_May-1987',
       'earliest_cr_line_is_May-1988', 'earliest_cr_line_is_May-1989',
       'earliest_cr_line_is_May-1990', 'earliest_cr_line_is_May-1991',
       'earliest_cr_line_is_May-1992', 'earliest_cr_line_is_May-1993',
       'earliest_cr_line_is_May-1994', 'earliest_cr_line_is_May-1995']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  \
# 0           0       5000    36     10.65       162.87
# 1           1       2500    60     15.27        59.83
# 2           2       2400    36     15.96        84.33
# 3           3      10000    36     13.49       339.31
# 4           4       3000    60     12.69        67.79
#
#                   emp_title home_ownership  annual_inc  verification_status  \
# 0                       NaN              0     24000.0                   -2
# 1                     Ryder              0     30000.0                   -1
# 2                       NaN              0     12252.0                    0
# 3       AIR RESOURCES BOARD              0     49200.0                   -1
# 4  University Medical Group              0     80000.0                   -1
#
#                                                 desc  ...  \
# 0    Borrower added on 12/22/11 > I need to upgra...  ...
# 1    Borrower added on 12/22/11 > I plan to use t...  ...
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'emp_title', 'home_ownership', 'annual_inc', 'verification_status',
#        'desc',
#        ...
#        'earliest_cr_line_is_Sep-1980', 'earliest_cr_line_is_Sep-1982',
#        'earliest_cr_line_is_Sep-2005', 'earliest_cr_line_is_Sep-2006',
#        'earliest_cr_line_is_Sep-2007', 'earliest_cr_line_is_Sep-2008',
#        'last_pymnt_d_is_Apr-2017', 'last_pymnt_d_is_Feb-2017',
#        'last_pymnt_d_is_Jan-2017', 'last_pymnt_d_is_Nov-2016'],
#       dtype='object', length=472)

# %%
cols =['earliest_cr_line_is_Mar-2003', 'earliest_cr_line_is_Mar-2004',
       'earliest_cr_line_is_May-1971', 'earliest_cr_line_is_May-1972',
       'earliest_cr_line_is_May-1973', 'earliest_cr_line_is_May-1975',
       'earliest_cr_line_is_May-1981', 'earliest_cr_line_is_May-1982',
       'earliest_cr_line_is_May-1983', 'earliest_cr_line_is_May-1984']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  \
# 0           0       5000    36     10.65       162.87
# 1           1       2500    60     15.27        59.83
# 2           2       2400    36     15.96        84.33
# 3           3      10000    36     13.49       339.31
# 4           4       3000    60     12.69        67.79
#
#                   emp_title home_ownership  annual_inc  verification_status  \
# 0                       NaN              0     24000.0                   -2
# 1                     Ryder              0     30000.0                   -1
# 2                       NaN              0     12252.0                    0
# 3       AIR RESOURCES BOARD              0     49200.0                   -1
# 4  University Medical Group              0     80000.0                   -1
#
#                                                 desc  ...  \
# 0    Borrower added on 12/22/11 > I need to upgra...  ...
# 1    Borrower added on 12/22/11 > I plan to use t...  ...
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'emp_title', 'home_ownership', 'annual_inc', 'verification_status',
#        'desc',
#        ...
#        'earliest_cr_line_is_Sep-1980', 'earliest_cr_line_is_Sep-1982',
#        'earliest_cr_line_is_Sep-2005', 'earliest_cr_line_is_Sep-2006',
#        'earliest_cr_line_is_Sep-2007', 'earliest_cr_line_is_Sep-2008',
#        'last_pymnt_d_is_Apr-2017', 'last_pymnt_d_is_Feb-2017',
#        'last_pymnt_d_is_Jan-2017', 'last_pymnt_d_is_Nov-2016'],
#       dtype='object', length=462)

# %%
cols =['earliest_cr_line_is_Mar-1993', 'earliest_cr_line_is_Mar-1994',
       'earliest_cr_line_is_Mar-1995', 'earliest_cr_line_is_Mar-1996',
       'earliest_cr_line_is_Mar-1997', 'earliest_cr_line_is_Mar-1998',
       'earliest_cr_line_is_Mar-1999', 'earliest_cr_line_is_Mar-2000',
       'earliest_cr_line_is_Mar-2001', 'earliest_cr_line_is_Mar-2002']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  \
# 0           0       5000    36     10.65       162.87
# 1           1       2500    60     15.27        59.83
# 2           2       2400    36     15.96        84.33
# 3           3      10000    36     13.49       339.31
# 4           4       3000    60     12.69        67.79
#
#                   emp_title home_ownership  annual_inc  verification_status  \
# 0                       NaN              0     24000.0                   -2
# 1                     Ryder              0     30000.0                   -1
# 2                       NaN              0     12252.0                    0
# 3       AIR RESOURCES BOARD              0     49200.0                   -1
# 4  University Medical Group              0     80000.0                   -1
#
#                                                 desc  ...  \
# 0    Borrower added on 12/22/11 > I need to upgra...  ...
# 1    Borrower added on 12/22/11 > I plan to use t...  ...
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'emp_title', 'home_ownership', 'annual_inc', 'verification_status',
#        'desc',
#        ...
#        'earliest_cr_line_is_Sep-1980', 'earliest_cr_line_is_Sep-1982',
#        'earliest_cr_line_is_Sep-2005', 'earliest_cr_line_is_Sep-2006',
#        'earliest_cr_line_is_Sep-2007', 'earliest_cr_line_is_Sep-2008',
#        'last_pymnt_d_is_Apr-2017', 'last_pymnt_d_is_Feb-2017',
#        'last_pymnt_d_is_Jan-2017', 'last_pymnt_d_is_Nov-2016'],
#       dtype='object', length=452)

# %%
cols =['earliest_cr_line_is_Mar-1983', 'earliest_cr_line_is_Mar-1984',
       'earliest_cr_line_is_Mar-1985', 'earliest_cr_line_is_Mar-1986',
       'earliest_cr_line_is_Mar-1987', 'earliest_cr_line_is_Mar-1988',
       'earliest_cr_line_is_Mar-1989', 'earliest_cr_line_is_Mar-1990',
       'earliest_cr_line_is_Mar-1991', 'earliest_cr_line_is_Mar-1992']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  \
# 0           0       5000    36     10.65       162.87
# 1           1       2500    60     15.27        59.83
# 2           2       2400    36     15.96        84.33
# 3           3      10000    36     13.49       339.31
# 4           4       3000    60     12.69        67.79
#
#                   emp_title home_ownership  annual_inc  verification_status  \
# 0                       NaN              0     24000.0                   -2
# 1                     Ryder              0     30000.0                   -1
# 2                       NaN              0     12252.0                    0
# 3       AIR RESOURCES BOARD              0     49200.0                   -1
# 4  University Medical Group              0     80000.0                   -1
#
#                                                 desc  ...  \
# 0    Borrower added on 12/22/11 > I need to upgra...  ...
# 1    Borrower added on 12/22/11 > I plan to use t...  ...
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'emp_title', 'home_ownership', 'annual_inc', 'verification_status',
#        'desc',
#        ...
#        'earliest_cr_line_is_Sep-1980', 'earliest_cr_line_is_Sep-1982',
#        'earliest_cr_line_is_Sep-2005', 'earliest_cr_line_is_Sep-2006',
#        'earliest_cr_line_is_Sep-2007', 'earliest_cr_line_is_Sep-2008',
#        'last_pymnt_d_is_Apr-2017', 'last_pymnt_d_is_Feb-2017',
#        'last_pymnt_d_is_Jan-2017', 'last_pymnt_d_is_Nov-2016'],
#       dtype='object', length=442)

# %%
cols =['earliest_cr_line_is_Jun-1996', 'earliest_cr_line_is_Jun-1997',
       'earliest_cr_line_is_Jun-1998', 'earliest_cr_line_is_Jun-1999',
       'earliest_cr_line_is_Jun-2000', 'earliest_cr_line_is_Jun-2001',
       'earliest_cr_line_is_Jun-2002', 'earliest_cr_line_is_Jun-2003',
       'earliest_cr_line_is_Jun-2004', 'earliest_cr_line_is_Mar-1982']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  \
# 0           0       5000    36     10.65       162.87
# 1           1       2500    60     15.27        59.83
# 2           2       2400    36     15.96        84.33
# 3           3      10000    36     13.49       339.31
# 4           4       3000    60     12.69        67.79
#
#                   emp_title home_ownership  annual_inc  verification_status  \
# 0                       NaN              0     24000.0                   -2
# 1                     Ryder              0     30000.0                   -1
# 2                       NaN              0     12252.0                    0
# 3       AIR RESOURCES BOARD              0     49200.0                   -1
# 4  University Medical Group              0     80000.0                   -1
#
#                                                 desc  ...  \
# 0    Borrower added on 12/22/11 > I need to upgra...  ...
# 1    Borrower added on 12/22/11 > I plan to use t...  ...
# ...

# %%
mapping_dict = {
            "home_ownership": {"RENT": 0, "OTHER":-4, "MORTGAGE": -3, "OWN": -2, "NONE": -1}, 
            "verification_status": {"Not Verified": 0, "Verified": -2, "Source Verified": -1},
            "purpose": {"debt_consolidation": 0,"educational": -13, "moving": -12, "vacation": -11, "house": -10, "renewable_energy": -9, "other": -8, "credit_card": -7,"home_improvement": -6,  
                "small_business": -5 ,"major_purchase": -4,  "car": -3,  "wedding": -2, 
                 "medical": -1}}
data = data.replace(mapping_dict)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  \
# 0           0       5000    36     10.65       162.87
# 1           1       2500    60     15.27        59.83
# 2           2       2400    36     15.96        84.33
# 3           3      10000    36     13.49       339.31
# 4           4       3000    60     12.69        67.79
#
#                   emp_title  home_ownership  annual_inc  verification_status  \
# 0                       NaN               0     24000.0                   -2
# 1                     Ryder               0     30000.0                   -1
# 2                       NaN               0     12252.0                    0
# 3       AIR RESOURCES BOARD               0     49200.0                   -1
# 4  University Medical Group               0     80000.0                   -1
#
#                                                 desc  ...  \
# 0    Borrower added on 12/22/11 > I need to upgra...  ...
# ...

# %%
cols = ['emp_title']
data = data.drop(cols, axis=1)
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'desc',
#        'purpose',
#        ...
#        'earliest_cr_line_is_Sep-1980', 'earliest_cr_line_is_Sep-1982',
#        'earliest_cr_line_is_Sep-2005', 'earliest_cr_line_is_Sep-2006',
#        'earliest_cr_line_is_Sep-2007', 'earliest_cr_line_is_Sep-2008',
#        'last_pymnt_d_is_Apr-2017', 'last_pymnt_d_is_Feb-2017',
#        'last_pymnt_d_is_Jan-2017', 'last_pymnt_d_is_Nov-2016'],
#       dtype='object', length=431)

# %%
cols = ['zip_code','total_pymnt',
        'total_pymnt_inv','total_rec_prncp','total_rec_int',
       'total_rec_late_fee','recoveries','collection_recovery_fee',
       'last_pymnt_amnt']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  \
# 0     24000.0                   -2
# 1     30000.0                   -1
# 2     12252.0                    0
# 3     49200.0                   -1
# 4     80000.0                   -1
#
#                                                 desc  purpose  ...  \
# 0    Borrower added on 12/22/11 > I need to upgra...       -7  ...
# 1    Borrower added on 12/22/11 > I plan to use t...       -3  ...
# 2                                                NaN       -5  ...
# ...

# %%
drop_columns = []

for col in data.columns:
    data[col].dropna(inplace=True)
    unique = data[col].unique()
    num_unique = len(unique)
    
    if num_unique == 1:
        drop_columns.append(col)
    else:
        pass
    
data = data.drop(drop_columns, axis=1)
print(drop_columns)
# Out:
# []

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'desc',
#        'purpose',
#        ...
#        'earliest_cr_line_is_Sep-1980', 'earliest_cr_line_is_Sep-1982',
#        'earliest_cr_line_is_Sep-2005', 'earliest_cr_line_is_Sep-2006',
#        'earliest_cr_line_is_Sep-2007', 'earliest_cr_line_is_Sep-2008',
#        'last_pymnt_d_is_Apr-2017', 'last_pymnt_d_is_Feb-2017',
#        'last_pymnt_d_is_Jan-2017', 'last_pymnt_d_is_Nov-2016'],
#       dtype='object', length=422)

# %%
cols = ['earliest_cr_line_is_Sep-1980', 'earliest_cr_line_is_Sep-1982',
       'earliest_cr_line_is_Sep-2005', 'earliest_cr_line_is_Sep-2006',
       'earliest_cr_line_is_Sep-2007', 'earliest_cr_line_is_Sep-2008',
       'last_pymnt_d_is_Apr-2017', 'last_pymnt_d_is_Feb-2017',
       'last_pymnt_d_is_Jan-2017', 'last_pymnt_d_is_Nov-2016','desc']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Sep-1968  earliest_cr_line_is_Sep-1969  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Sep-1968', 'earliest_cr_line_is_Sep-1969',
#        'earliest_cr_line_is_Sep-1970', 'earliest_cr_line_is_Sep-1971',
#        'earliest_cr_line_is_Sep-1972', 'earliest_cr_line_is_Sep-1974',
#        'earliest_cr_line_is_Sep-1975', 'earliest_cr_line_is_Sep-1977',
#        'earliest_cr_line_is_Sep-1978', 'earliest_cr_line_is_Sep-1979'],
#       dtype='object', length=411)

# %%
cols = ['earliest_cr_line_is_Sep-1968', 'earliest_cr_line_is_Sep-1969',
       'earliest_cr_line_is_Sep-1970', 'earliest_cr_line_is_Sep-1971',
       'earliest_cr_line_is_Sep-1972', 'earliest_cr_line_is_Sep-1974',
       'earliest_cr_line_is_Sep-1975', 'earliest_cr_line_is_Sep-1977',
       'earliest_cr_line_is_Sep-1978', 'earliest_cr_line_is_Sep-1979']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Oct-1988  earliest_cr_line_is_Oct-2005  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Oct-1988', 'earliest_cr_line_is_Oct-2005',
#        'earliest_cr_line_is_Oct-2006', 'earliest_cr_line_is_Oct-2007',
#        'earliest_cr_line_is_Oct-2008', 'earliest_cr_line_is_Sep-1956',
#        'earliest_cr_line_is_Sep-1962', 'earliest_cr_line_is_Sep-1963',
#        'earliest_cr_line_is_Sep-1965', 'earliest_cr_line_is_Sep-1967'],
#       dtype='object', length=401)

# %%
cols = ['earliest_cr_line_is_Oct-1988', 'earliest_cr_line_is_Oct-2005',
       'earliest_cr_line_is_Oct-2006', 'earliest_cr_line_is_Oct-2007',
       'earliest_cr_line_is_Oct-2008', 'earliest_cr_line_is_Sep-1956',
       'earliest_cr_line_is_Sep-1962', 'earliest_cr_line_is_Sep-1963',
       'earliest_cr_line_is_Sep-1965', 'earliest_cr_line_is_Sep-1967']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Oct-1975  earliest_cr_line_is_Oct-1976  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Oct-1975', 'earliest_cr_line_is_Oct-1976',
#        'earliest_cr_line_is_Oct-1977', 'earliest_cr_line_is_Oct-1978',
#        'earliest_cr_line_is_Oct-1981', 'earliest_cr_line_is_Oct-1982',
#        'earliest_cr_line_is_Oct-1983', 'earliest_cr_line_is_Oct-1985',
#        'earliest_cr_line_is_Oct-1986', 'earliest_cr_line_is_Oct-1987'],
#       dtype='object', length=391)

# %%
cols = ['earliest_cr_line_is_Oct-1975', 'earliest_cr_line_is_Oct-1976',
       'earliest_cr_line_is_Oct-1977', 'earliest_cr_line_is_Oct-1978',
       'earliest_cr_line_is_Oct-1981', 'earliest_cr_line_is_Oct-1982',
       'earliest_cr_line_is_Oct-1983', 'earliest_cr_line_is_Oct-1985',
       'earliest_cr_line_is_Oct-1986', 'earliest_cr_line_is_Oct-1987']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Oct-1964  earliest_cr_line_is_Oct-1965  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Oct-1964', 'earliest_cr_line_is_Oct-1965',
#        'earliest_cr_line_is_Oct-1967', 'earliest_cr_line_is_Oct-1968',
#        'earliest_cr_line_is_Oct-1969', 'earliest_cr_line_is_Oct-1970',
#        'earliest_cr_line_is_Oct-1971', 'earliest_cr_line_is_Oct-1972',
#        'earliest_cr_line_is_Oct-1973', 'earliest_cr_line_is_Oct-1974'],
#       dtype='object', length=381)

# %%
cols = ['earliest_cr_line_is_Oct-1964', 'earliest_cr_line_is_Oct-1965',
       'earliest_cr_line_is_Oct-1967', 'earliest_cr_line_is_Oct-1968',
       'earliest_cr_line_is_Oct-1969', 'earliest_cr_line_is_Oct-1970',
       'earliest_cr_line_is_Oct-1971', 'earliest_cr_line_is_Oct-1972',
       'earliest_cr_line_is_Oct-1973', 'earliest_cr_line_is_Oct-1974']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Nov-1977  earliest_cr_line_is_Nov-1978  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Nov-1977', 'earliest_cr_line_is_Nov-1978',
#        'earliest_cr_line_is_Nov-1979', 'earliest_cr_line_is_Nov-1980',
#        'earliest_cr_line_is_Nov-2005', 'earliest_cr_line_is_Nov-2006',
#        'earliest_cr_line_is_Nov-2007', 'earliest_cr_line_is_Nov-2008',
#        'earliest_cr_line_is_Oct-1954', 'earliest_cr_line_is_Oct-1963'],
#       dtype='object', length=371)

# %%
cols = ['earliest_cr_line_is_Nov-1977', 'earliest_cr_line_is_Nov-1978',
       'earliest_cr_line_is_Nov-1979', 'earliest_cr_line_is_Nov-1980',
       'earliest_cr_line_is_Nov-2005', 'earliest_cr_line_is_Nov-2006',
       'earliest_cr_line_is_Nov-2007', 'earliest_cr_line_is_Nov-2008',
       'earliest_cr_line_is_Oct-1954', 'earliest_cr_line_is_Oct-1963']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Nov-1965  earliest_cr_line_is_Nov-1966  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Nov-1965', 'earliest_cr_line_is_Nov-1966',
#        'earliest_cr_line_is_Nov-1967', 'earliest_cr_line_is_Nov-1968',
#        'earliest_cr_line_is_Nov-1969', 'earliest_cr_line_is_Nov-1970',
#        'earliest_cr_line_is_Nov-1971', 'earliest_cr_line_is_Nov-1973',
#        'earliest_cr_line_is_Nov-1974', 'earliest_cr_line_is_Nov-1975'],
#       dtype='object', length=361)

# %%
cols = ['earliest_cr_line_is_Nov-1965', 'earliest_cr_line_is_Nov-1966',
       'earliest_cr_line_is_Nov-1967', 'earliest_cr_line_is_Nov-1968',
       'earliest_cr_line_is_Nov-1969', 'earliest_cr_line_is_Nov-1970',
       'earliest_cr_line_is_Nov-1971', 'earliest_cr_line_is_Nov-1973',
       'earliest_cr_line_is_Nov-1974', 'earliest_cr_line_is_Nov-1975']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_May-1979  earliest_cr_line_is_May-1980  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_May-1979', 'earliest_cr_line_is_May-1980',
#        'earliest_cr_line_is_May-1986', 'earliest_cr_line_is_May-2005',
#        'earliest_cr_line_is_May-2006', 'earliest_cr_line_is_May-2007',
#        'earliest_cr_line_is_May-2008', 'earliest_cr_line_is_Nov-1954',
#        'earliest_cr_line_is_Nov-1961', 'earliest_cr_line_is_Nov-1962'],
#       dtype='object', length=351)

# %%
cols = ['earliest_cr_line_is_May-1979', 'earliest_cr_line_is_May-1980',
       'earliest_cr_line_is_May-1986', 'earliest_cr_line_is_May-2005',
       'earliest_cr_line_is_May-2006', 'earliest_cr_line_is_May-2007',
       'earliest_cr_line_is_May-2008', 'earliest_cr_line_is_Nov-1954',
       'earliest_cr_line_is_Nov-1961', 'earliest_cr_line_is_Nov-1962']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Mar-2007  earliest_cr_line_is_Mar-2008  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Mar-2007', 'earliest_cr_line_is_Mar-2008',
#        'earliest_cr_line_is_May-1963', 'earliest_cr_line_is_May-1965',
#        'earliest_cr_line_is_May-1967', 'earliest_cr_line_is_May-1970',
#        'earliest_cr_line_is_May-1974', 'earliest_cr_line_is_May-1976',
#        'earliest_cr_line_is_May-1977', 'earliest_cr_line_is_May-1978'],
#       dtype='object', length=341)

# %%
cols = ['earliest_cr_line_is_Mar-2007', 'earliest_cr_line_is_Mar-2008',
       'earliest_cr_line_is_May-1963', 'earliest_cr_line_is_May-1965',
       'earliest_cr_line_is_May-1967', 'earliest_cr_line_is_May-1970',
       'earliest_cr_line_is_May-1974', 'earliest_cr_line_is_May-1976',
       'earliest_cr_line_is_May-1977', 'earliest_cr_line_is_May-1978']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Mar-1974  earliest_cr_line_is_Mar-1975  \
# 0                             0                             0
# 1                             0                             0
# ...

# %% [markdown]
# data.columns

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Mar-1974', 'earliest_cr_line_is_Mar-1975',
#        'earliest_cr_line_is_Mar-1976', 'earliest_cr_line_is_Mar-1977',
#        'earliest_cr_line_is_Mar-1978', 'earliest_cr_line_is_Mar-1979',
#        'earliest_cr_line_is_Mar-1980', 'earliest_cr_line_is_Mar-1981',
#        'earliest_cr_line_is_Mar-2005', 'earliest_cr_line_is_Mar-2006'],
#       dtype='object', length=331)

# %%
cols = ['earliest_cr_line_is_Mar-1974', 'earliest_cr_line_is_Mar-1975',
       'earliest_cr_line_is_Mar-1976', 'earliest_cr_line_is_Mar-1977',
       'earliest_cr_line_is_Mar-1978', 'earliest_cr_line_is_Mar-1979',
       'earliest_cr_line_is_Mar-1980', 'earliest_cr_line_is_Mar-1981',
       'earliest_cr_line_is_Mar-2005', 'earliest_cr_line_is_Mar-2006']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jun-2007  earliest_cr_line_is_Jun-2008  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jun-2007', 'earliest_cr_line_is_Jun-2008',
#        'earliest_cr_line_is_Mar-1963', 'earliest_cr_line_is_Mar-1966',
#        'earliest_cr_line_is_Mar-1968', 'earliest_cr_line_is_Mar-1969',
#        'earliest_cr_line_is_Mar-1970', 'earliest_cr_line_is_Mar-1971',
#        'earliest_cr_line_is_Mar-1972', 'earliest_cr_line_is_Mar-1973'],
#       dtype='object', length=321)

# %%
cols = ['earliest_cr_line_is_Jun-2007', 'earliest_cr_line_is_Jun-2008',
       'earliest_cr_line_is_Mar-1963', 'earliest_cr_line_is_Mar-1966',
       'earliest_cr_line_is_Mar-1968', 'earliest_cr_line_is_Mar-1969',
       'earliest_cr_line_is_Mar-1970', 'earliest_cr_line_is_Mar-1971',
       'earliest_cr_line_is_Mar-1972', 'earliest_cr_line_is_Mar-1973']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jun-1988  earliest_cr_line_is_Jun-1989  \
# 0                             0                             0
# 1                             0                             0
# ...

# %% [markdown]
# data.columns

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jun-1988', 'earliest_cr_line_is_Jun-1989',
#        'earliest_cr_line_is_Jun-1990', 'earliest_cr_line_is_Jun-1991',
#        'earliest_cr_line_is_Jun-1992', 'earliest_cr_line_is_Jun-1993',
#        'earliest_cr_line_is_Jun-1994', 'earliest_cr_line_is_Jun-1995',
#        'earliest_cr_line_is_Jun-2005', 'earliest_cr_line_is_Jun-2006'],
#       dtype='object', length=311)

# %%
cols = ['earliest_cr_line_is_Jun-1988', 'earliest_cr_line_is_Jun-1989',
       'earliest_cr_line_is_Jun-1990', 'earliest_cr_line_is_Jun-1991',
       'earliest_cr_line_is_Jun-1992', 'earliest_cr_line_is_Jun-1993',
       'earliest_cr_line_is_Jun-1994', 'earliest_cr_line_is_Jun-1995',
       'earliest_cr_line_is_Jun-2005', 'earliest_cr_line_is_Jun-2006']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jun-1978  earliest_cr_line_is_Jun-1979  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jun-1978', 'earliest_cr_line_is_Jun-1979',
#        'earliest_cr_line_is_Jun-1980', 'earliest_cr_line_is_Jun-1981',
#        'earliest_cr_line_is_Jun-1982', 'earliest_cr_line_is_Jun-1983',
#        'earliest_cr_line_is_Jun-1984', 'earliest_cr_line_is_Jun-1985',
#        'earliest_cr_line_is_Jun-1986', 'earliest_cr_line_is_Jun-1987'],
#       dtype='object', length=301)

# %%
cols = [ 'earliest_cr_line_is_Jun-1978', 'earliest_cr_line_is_Jun-1979',
       'earliest_cr_line_is_Jun-1980', 'earliest_cr_line_is_Jun-1981',
       'earliest_cr_line_is_Jun-1982', 'earliest_cr_line_is_Jun-1983',
       'earliest_cr_line_is_Jun-1984', 'earliest_cr_line_is_Jun-1985',
       'earliest_cr_line_is_Jun-1986', 'earliest_cr_line_is_Jun-1987']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jun-1968  earliest_cr_line_is_Jun-1969  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jun-1968', 'earliest_cr_line_is_Jun-1969',
#        'earliest_cr_line_is_Jun-1970', 'earliest_cr_line_is_Jun-1971',
#        'earliest_cr_line_is_Jun-1972', 'earliest_cr_line_is_Jun-1973',
#        'earliest_cr_line_is_Jun-1974', 'earliest_cr_line_is_Jun-1975',
#        'earliest_cr_line_is_Jun-1976', 'earliest_cr_line_is_Jun-1977'],
#       dtype='object', length=291)

# %%
cols = [ 'earliest_cr_line_is_Jun-1968', 'earliest_cr_line_is_Jun-1969',
       'earliest_cr_line_is_Jun-1970', 'earliest_cr_line_is_Jun-1971',
       'earliest_cr_line_is_Jun-1972', 'earliest_cr_line_is_Jun-1973',
       'earliest_cr_line_is_Jun-1974', 'earliest_cr_line_is_Jun-1975',
       'earliest_cr_line_is_Jun-1976', 'earliest_cr_line_is_Jun-1977']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
#        'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
#        'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
#        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967'],
#       dtype='object', length=281)

# %%
cols = [ 'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
       'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
       'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
       'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
       'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967','Unnamed: 0']
data = data.drop(cols, axis=1)
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-274-d2fbe7adaa3d> in <module>
#       4        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#       5        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967','Unnamed: 0']
# ----> 6 data = data.drop(cols, axis=1)
#       7 data.head()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
#        'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
#        'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
#        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967'],
#       dtype='object', length=281)

# %%
cols = [ 'earliest_cr_line_is_Jul-1992', 'earliest_cr_line_is_Jul-1993',
       'earliest_cr_line_is_Jul-1994', 'earliest_cr_line_is_Jul-1995',
       'earliest_cr_line_is_Jul-1996', 'earliest_cr_line_is_Jul-1997',
       'earliest_cr_line_is_Jul-1998', 'earliest_cr_line_is_Jul-1999',
       'earliest_cr_line_is_Jul-2000', 'earliest_cr_line_is_Jul-2001']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
#        'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
#        'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
#        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967'],
#       dtype='object', length=271)

# %%
cols = [ 'earliest_cr_line_is_Jul-1982', 'earliest_cr_line_is_Jul-1983',
       'earliest_cr_line_is_Jul-1984', 'earliest_cr_line_is_Jul-1985',
       'earliest_cr_line_is_Jul-1986', 'earliest_cr_line_is_Jul-1987',
       'earliest_cr_line_is_Jul-1988', 'earliest_cr_line_is_Jul-1989',
       'earliest_cr_line_is_Jul-1990', 'earliest_cr_line_is_Jul-1991']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
#        'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
#        'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
#        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967'],
#       dtype='object', length=261)

# %%
cols = [ 'earliest_cr_line_is_Jul-1972', 'earliest_cr_line_is_Jul-1973',
       'earliest_cr_line_is_Jul-1974', 'earliest_cr_line_is_Jul-1975',
       'earliest_cr_line_is_Jul-1976', 'earliest_cr_line_is_Jul-1977',
       'earliest_cr_line_is_Jul-1978', 'earliest_cr_line_is_Jul-1979',
       'earliest_cr_line_is_Jul-1980', 'earliest_cr_line_is_Jul-1981']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
#        'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
#        'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
#        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967'],
#       dtype='object', length=251)

# %%
cols = [ 'earliest_cr_line_is_Jan-2004', 'earliest_cr_line_is_Jan-2005',
       'earliest_cr_line_is_Jan-2006', 'earliest_cr_line_is_Jan-2007',
       'earliest_cr_line_is_Jan-2008', 'earliest_cr_line_is_Jul-1964',
       'earliest_cr_line_is_Jul-1967', 'earliest_cr_line_is_Jul-1969',
       'earliest_cr_line_is_Jul-1970', 'earliest_cr_line_is_Jul-1971']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
#        'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
#        'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
#        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967'],
#       dtype='object', length=241)

# %%
cols = [ 'earliest_cr_line_is_Jan-1993', 'earliest_cr_line_is_Jan-1994',
       'earliest_cr_line_is_Jan-1995', 'earliest_cr_line_is_Jan-1996',
       'earliest_cr_line_is_Jan-1997', 'earliest_cr_line_is_Jan-1998',
       'earliest_cr_line_is_Jan-1999', 'earliest_cr_line_is_Jan-2001',
       'earliest_cr_line_is_Jan-2002', 'earliest_cr_line_is_Jan-2003']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
#        'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
#        'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
#        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967'],
#       dtype='object', length=231)

# %%
cols = [ 'earliest_cr_line_is_Jan-1983', 'earliest_cr_line_is_Jan-1984',
       'earliest_cr_line_is_Jan-1985', 'earliest_cr_line_is_Jan-1986',
       'earliest_cr_line_is_Jan-1987', 'earliest_cr_line_is_Jan-1988',
       'earliest_cr_line_is_Jan-1989', 'earliest_cr_line_is_Jan-1990',
       'earliest_cr_line_is_Jan-1991', 'earliest_cr_line_is_Jan-1992']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
#        'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
#        'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
#        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967'],
#       dtype='object', length=221)

# %%
cols = [ 'earliest_cr_line_is_Jan-1973', 'earliest_cr_line_is_Jan-1974',
       'earliest_cr_line_is_Jan-1975', 'earliest_cr_line_is_Jan-1976',
       'earliest_cr_line_is_Jan-1977', 'earliest_cr_line_is_Jan-1978',
       'earliest_cr_line_is_Jan-1979', 'earliest_cr_line_is_Jan-1980',
       'earliest_cr_line_is_Jan-1981', 'earliest_cr_line_is_Jan-1982']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
#        'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
#        'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
#        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967'],
#       dtype='object', length=211)

# %%
cols = [ 'earliest_cr_line_is_Feb-2005', 'earliest_cr_line_is_Feb-2006',
       'earliest_cr_line_is_Feb-2007', 'earliest_cr_line_is_Feb-2008',
       'earliest_cr_line_is_Jan-1946', 'earliest_cr_line_is_Jan-1963',
       'earliest_cr_line_is_Jan-1968', 'earliest_cr_line_is_Jan-1970',
       'earliest_cr_line_is_Jan-1971', 'earliest_cr_line_is_Jan-1972']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
#        'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
#        'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
#        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967'],
#       dtype='object', length=201)

# %%
cols = [  'earliest_cr_line_is_Feb-1995', 'earliest_cr_line_is_Feb-1996',
       'earliest_cr_line_is_Feb-1997', 'earliest_cr_line_is_Feb-1998',
       'earliest_cr_line_is_Feb-1999', 'earliest_cr_line_is_Feb-2000',
       'earliest_cr_line_is_Feb-2001', 'earliest_cr_line_is_Feb-2002',
       'earliest_cr_line_is_Feb-2003', 'earliest_cr_line_is_Feb-2004']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
#        'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
#        'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
#        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967'],
#       dtype='object', length=191)

# %%
cols = [   'earliest_cr_line_is_Feb-1985', 'earliest_cr_line_is_Feb-1986',
       'earliest_cr_line_is_Feb-1987', 'earliest_cr_line_is_Feb-1988',
       'earliest_cr_line_is_Feb-1989', 'earliest_cr_line_is_Feb-1990',
       'earliest_cr_line_is_Feb-1991', 'earliest_cr_line_is_Feb-1992',
       'earliest_cr_line_is_Feb-1993', 'earliest_cr_line_is_Feb-1994']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
#        'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
#        'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
#        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967'],
#       dtype='object', length=181)

# %%
cols = [   'earliest_cr_line_is_Feb-1975', 'earliest_cr_line_is_Feb-1976',
       'earliest_cr_line_is_Feb-1977', 'earliest_cr_line_is_Feb-1978',
       'earliest_cr_line_is_Feb-1979', 'earliest_cr_line_is_Feb-1980',
       'earliest_cr_line_is_Feb-1981', 'earliest_cr_line_is_Feb-1982',
       'earliest_cr_line_is_Feb-1983', 'earliest_cr_line_is_Feb-1984']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
#        'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
#        'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
#        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967'],
#       dtype='object', length=171)

# %%
cols = [ 'earliest_cr_line_is_Feb-1965', 'earliest_cr_line_is_Feb-1966',
       'earliest_cr_line_is_Feb-1967', 'earliest_cr_line_is_Feb-1968',
       'earliest_cr_line_is_Feb-1969', 'earliest_cr_line_is_Feb-1970',
       'earliest_cr_line_is_Feb-1971', 'earliest_cr_line_is_Feb-1972',
       'earliest_cr_line_is_Feb-1973', 'earliest_cr_line_is_Feb-1974']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
#        'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
#        'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
#        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967'],
#       dtype='object', length=161)

# %%
cols = [  'earliest_cr_line_is_Dec-1998', 'earliest_cr_line_is_Dec-1999',
       'earliest_cr_line_is_Dec-2000', 'earliest_cr_line_is_Dec-2001',
       'earliest_cr_line_is_Dec-2002', 'earliest_cr_line_is_Dec-2003',
       'earliest_cr_line_is_Dec-2004', 'earliest_cr_line_is_Dec-2005',
       'earliest_cr_line_is_Dec-2006', 'earliest_cr_line_is_Dec-2007']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
#        'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
#        'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
#        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967'],
#       dtype='object', length=151)

# %%
cols = [  'earliest_cr_line_is_Dec-1988', 'earliest_cr_line_is_Dec-1989',
       'earliest_cr_line_is_Dec-1990', 'earliest_cr_line_is_Dec-1991',
       'earliest_cr_line_is_Dec-1992', 'earliest_cr_line_is_Dec-1993',
       'earliest_cr_line_is_Dec-1994', 'earliest_cr_line_is_Dec-1995',
       'earliest_cr_line_is_Dec-1996', 'earliest_cr_line_is_Dec-1997']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
#        'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
#        'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
#        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967'],
#       dtype='object', length=141)

# %%
cols = [ 'earliest_cr_line_is_Dec-1978', 'earliest_cr_line_is_Dec-1979',
       'earliest_cr_line_is_Dec-1980', 'earliest_cr_line_is_Dec-1981',
       'earliest_cr_line_is_Dec-1982', 'earliest_cr_line_is_Dec-1983',
       'earliest_cr_line_is_Dec-1984', 'earliest_cr_line_is_Dec-1985',
       'earliest_cr_line_is_Dec-1986', 'earliest_cr_line_is_Dec-1987']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
#        'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
#        'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
#        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967'],
#       dtype='object', length=131)

# %%
cols = [ 'earliest_cr_line_is_Dec-1966', 'earliest_cr_line_is_Dec-1968',
       'earliest_cr_line_is_Dec-1969', 'earliest_cr_line_is_Dec-1970',
       'earliest_cr_line_is_Dec-1972', 'earliest_cr_line_is_Dec-1973',
       'earliest_cr_line_is_Dec-1974', 'earliest_cr_line_is_Dec-1975',
       'earliest_cr_line_is_Dec-1976', 'earliest_cr_line_is_Dec-1977']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
#        'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
#        'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
#        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967'],
#       dtype='object', length=121)

# %%
cols = [ 'earliest_cr_line_is_Aug-2003', 'earliest_cr_line_is_Aug-2004',
       'earliest_cr_line_is_Aug-2005', 'earliest_cr_line_is_Aug-2006',
       'earliest_cr_line_is_Aug-2007', 'earliest_cr_line_is_Aug-2008',
       'earliest_cr_line_is_Dec-1950', 'earliest_cr_line_is_Dec-1961',
       'earliest_cr_line_is_Dec-1963', 'earliest_cr_line_is_Dec-1965']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        ...
#        'earliest_cr_line_is_Jul-2002', 'earliest_cr_line_is_Jul-2003',
#        'earliest_cr_line_is_Jul-2004', 'earliest_cr_line_is_Jul-2005',
#        'earliest_cr_line_is_Jul-2006', 'earliest_cr_line_is_Jul-2007',
#        'earliest_cr_line_is_Jul-2008', 'earliest_cr_line_is_Jun-1959',
#        'earliest_cr_line_is_Jun-1966', 'earliest_cr_line_is_Jun-1967'],
#       dtype='object', length=111)

# %%
cols = [ 'issue_d_is_2007-06-01 00:00:00',
       'issue_d_is_2007-07-01 00:00:00', 'earliest_cr_line_is_Apr-1964',
       'earliest_cr_line_is_Apr-1966', 'earliest_cr_line_is_Apr-1967',
       'earliest_cr_line_is_Apr-1969', 'earliest_cr_line_is_Apr-1970',
       'earliest_cr_line_is_Apr-1971', 'earliest_cr_line_is_Apr-1972',
       'earliest_cr_line_is_Apr-1973', 'earliest_cr_line_is_Apr-1974',
       'earliest_cr_line_is_Apr-1975', 'earliest_cr_line_is_Apr-1976',
       'earliest_cr_line_is_Apr-1977', 'earliest_cr_line_is_Apr-1978',
       'earliest_cr_line_is_Apr-1979', 'earliest_cr_line_is_Apr-1980',
       'earliest_cr_line_is_Apr-1981', 'earliest_cr_line_is_Apr-1982',
       'earliest_cr_line_is_Apr-1983', 'earliest_cr_line_is_Apr-1984',
       'earliest_cr_line_is_Apr-1985', 'earliest_cr_line_is_Apr-1986',
       'earliest_cr_line_is_Apr-1987', 'earliest_cr_line_is_Apr-1988',
       'earliest_cr_line_is_Apr-1989', 'earliest_cr_line_is_Apr-1990',
       'earliest_cr_line_is_Apr-1991', 'earliest_cr_line_is_Apr-1992',
       'earliest_cr_line_is_Apr-1993', 'earliest_cr_line_is_Apr-1994',
       'earliest_cr_line_is_Apr-1995', 'earliest_cr_line_is_Apr-1996',
       'earliest_cr_line_is_Apr-1997', 'earliest_cr_line_is_Apr-1998',
       'earliest_cr_line_is_Apr-1999', 'earliest_cr_line_is_Apr-2000',
       'earliest_cr_line_is_Apr-2001', 'earliest_cr_line_is_Apr-2002',
       'earliest_cr_line_is_Apr-2003', 'earliest_cr_line_is_Apr-2004',
       'earliest_cr_line_is_Apr-2005', 'earliest_cr_line_is_Apr-2006',
       'earliest_cr_line_is_Apr-2007', 'earliest_cr_line_is_Apr-2008',
       'earliest_cr_line_is_Aug-1967', 'earliest_cr_line_is_Aug-1968',
       'earliest_cr_line_is_Aug-1969', 'earliest_cr_line_is_Aug-1970',
       'earliest_cr_line_is_Aug-1971', 'earliest_cr_line_is_Aug-1972',
       'earliest_cr_line_is_Aug-1973', 'earliest_cr_line_is_Aug-1974',
       'earliest_cr_line_is_Aug-1975', 'earliest_cr_line_is_Aug-1976',
       'earliest_cr_line_is_Aug-1977', 'earliest_cr_line_is_Aug-1978',
       'earliest_cr_line_is_Aug-1979', 'earliest_cr_line_is_Aug-1980',
       'earliest_cr_line_is_Aug-1981', 'earliest_cr_line_is_Aug-1982',
       'earliest_cr_line_is_Aug-1983', 'earliest_cr_line_is_Aug-1984',
       'earliest_cr_line_is_Aug-1985', 'earliest_cr_line_is_Aug-1986',
       'earliest_cr_line_is_Aug-1987', 'earliest_cr_line_is_Aug-1988',
       'earliest_cr_line_is_Aug-1989', 'earliest_cr_line_is_Aug-1990',
       'earliest_cr_line_is_Aug-1991', 'earliest_cr_line_is_Aug-1992',
       'earliest_cr_line_is_Aug-1993', 'earliest_cr_line_is_Aug-1994',
       'earliest_cr_line_is_Aug-1995', 'earliest_cr_line_is_Aug-1996',
       'earliest_cr_line_is_Aug-1997', 'earliest_cr_line_is_Aug-1998',
       'earliest_cr_line_is_Aug-1999', 'earliest_cr_line_is_Aug-2000',
       'earliest_cr_line_is_Aug-2001', 'earliest_cr_line_is_Aug-2002']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'pub_rec_bankruptcies',
#        'home_ownership_is_OTHER', 'default', 'earliest_cr_line_is_Jul-2002',
#        'earliest_cr_line_is_Jul-2003', 'earliest_cr_line_is_Jul-2004',
#        'earliest_cr_line_is_Jul-2005', 'earliest_cr_line_is_Jul-2006',
#        'earliest_cr_line_is_Jul-2007', 'earliest_cr_line_is_Jul-2008',
#        'earliest_cr_line_is_Jun-1959', 'earliest_cr_line_is_Jun-1966',
#        'earliest_cr_line_is_Jun-1967'],
#       dtype='object')

# %%
data.shape
# Out:
# (39786, 30)

# %%
cols = [ 'pub_rec_bankruptcies']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.to_csv(r'cf_loans_clean29.csv',index=False)

# %%
data.shape
# Out:
# (39786, 29)

# %%
cols = ['home_ownership_is_OTHER']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  ...  \
# 0     24000.0                   -2       -7  27.65  ...
# 1     30000.0                   -1       -3   1.00  ...
# 2     12252.0                    0       -5   8.72  ...
# 3     49200.0                   -1       -8  20.00  ...
# 4     80000.0                   -1       -8  17.94  ...
#
#    earliest_cr_line_is_Jul-2002  earliest_cr_line_is_Jul-2003  \
# 0                             0                             0
# 1                             0                             0
# ...

# %%
data.columns
# Out:
# Index(['emp_length', 'loan_amnt', 'term', 'int_rate', 'installment',
#        'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'default', 'earliest_cr_line_is_Jul-2002',
#        'earliest_cr_line_is_Jul-2003', 'earliest_cr_line_is_Jul-2004',
#        'earliest_cr_line_is_Jul-2005', 'earliest_cr_line_is_Jul-2006',
#        'earliest_cr_line_is_Jul-2007', 'earliest_cr_line_is_Jul-2008',
#        'earliest_cr_line_is_Jun-1959', 'earliest_cr_line_is_Jun-1966',
#        'earliest_cr_line_is_Jun-1967'],
#       dtype='object')

# %%
cols = ['earliest_cr_line_is_Jul-2002',
       'earliest_cr_line_is_Jul-2003', 'earliest_cr_line_is_Jul-2004',
       'earliest_cr_line_is_Jul-2005', 'earliest_cr_line_is_Jul-2006',
       'earliest_cr_line_is_Jul-2007', 'earliest_cr_line_is_Jul-2008',
       'earliest_cr_line_is_Jun-1959', 'earliest_cr_line_is_Jun-1966',
       'earliest_cr_line_is_Jun-1967']
data = data.drop(cols, axis=1)
data.head()
# Out:
#    emp_length  loan_amnt  term  int_rate  installment  home_ownership  \
# 0           0       5000    36     10.65       162.87               0
# 1           1       2500    60     15.27        59.83               0
# 2           2       2400    36     15.96        84.33               0
# 3           3      10000    36     13.49       339.31               0
# 4           4       3000    60     12.69        67.79               0
#
#    annual_inc  verification_status  purpose    dti  delinq_2yrs  \
# 0     24000.0                   -2       -7  27.65            0
# 1     30000.0                   -1       -3   1.00            0
# 2     12252.0                    0       -5   8.72            0
# 3     49200.0                   -1       -8  20.00            0
# 4     80000.0                   -1       -8  17.94            0
#
#    inq_last_6mths  open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 0               1         3        0      13648        83.7          9
# ...

# %%
data.shape
# Out:
# (39786, 18)

# %%
data.to_csv(r'cf_loans_clean31.csv',index=False)
